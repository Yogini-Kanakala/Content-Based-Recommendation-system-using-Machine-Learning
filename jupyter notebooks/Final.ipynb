# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
import warnings

import numpy as np
import pandas as pd

warnings.filterwarnings('ignore')

import re

import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from sklearn.pipeline import make_pipeline

# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')

stemmer = PorterStemmer()
features = ['Product_ID', 'Name', 'Brand', 'Taxonomy_List', 'Keywords']
def preprocess_text(text):
    text = text.lower()
    text = re.sub('<.*?>', '', text)
    text = re.sub(r'http\S+', '', text)
    text = re.sub('[^a-zA-Z]', ' ', text)
    words = nltk.word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    words = [stemmer.stem(word) for word in words]
    text = ' '.join(words)
    return text

def clean_taxonomy(raw_taxonomy):
    words = raw_taxonomy.split('|')
    words = [x for word in words for x in word.split('>')]
    words = [word.lower() for word in words]
    return "  ".join(words)


def preprocess_data(df):
    df.fillna('Missing', inplace=True)
    df.Name = df.Name.apply(preprocess_text)
    df.Taxonomy_List = df.Taxonomy_List.apply(clean_taxonomy)
#     df.Brand = df.Brand.str.lower()
#     df.Keywords = df.Keywords.apply(preprocess_text)
    return df
    

def generate_vectors(df):
#     documents = (df.Name + " " + df.Brand + " " + df.Taxonomy_List + " " + df.Keywords).tolist()
    documents = df.Taxonomy_List.tolist()
    vectorizer = TfidfVectorizer(stop_words='english', max_features=10000)
    tfidf_vectors = vectorizer.fit_transform(documents)
    nn_model = NearestNeighbors(n_neighbors=10, algorithm='brute')
    nn_model.fit(tfidf_vectors)
    return vectorizer, nn_model

def preprocess_input(text):
    text = text.lower()
    text = re.sub('[^a-zA-Z]', ' ', text)
    words = nltk.word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    words = [stemmer.stem(word) for word in words]
    text = ' '.join(words)
    return text
    
    
def get_product_vector(product_id, id_to_index, vectors):
    indx = id_to_index[product_id]
    vector = vectors[indx]
    return vector

def recommend_products(product_id, vectors, nn_model, main_df, n=10):
#     new_document = preprocess_input(query)
#     new_tfidf_vector = vectorizer.transform([new_document])
    new_tfidf_vector = get_product_vector(product_id)
    _, indices = nn_model.kneighbors(new_tfidf_vector,n_neighbors=n)
    res = main_df.iloc[indices[0]].reset_index(drop=True)
    return dict(res)

# %%
#from utils import preprocess_data, generate_vectors
# import pandas as pd
import pickle


main_df = pd.read_csv("../data/mast_product_level_information.csv")
df = preprocess_data(main_df)

print("data loaded..")

vectorizer, model = generate_vectors(df)

print('vectors generated')

with open('feature_store/model.pkl', 'wb') as f:
    pickle.dump(model, f)

with open('feature_store/vectorizer.pkl', 'wb') as f:
    pickle.dump(vectorizer, f)

print('models saved..')
# Out:
# data loaded..
# vectors generated
# models saved..

# %%
nn_model = pickle.load(open('feature_store/model.pkl', 'rb'))
vectorizer = pickle.load(open('feature_store/vectorizer.pkl', 'rb'))
main_df = pd.read_csv('../data/mast_product_level_information.csv')
query = input('Search: ')

res = recommend_products(query, vectorizer, nn_model, main_df, n=10)

pd.DataFrame(res)
# Out:
# Search: t shirt
#    Product_ID             Style  \
# 0      226574         LS_BESTIE
# 1      226572      LS_DIFFERENT
# 2      187984              1001
# 3      198206   DEBB_MGS_F22_LS
# 4      207104  KT_980_06SP10193
# 5      141645       TRI_STAR_LS
# 6      226578       LS_FARMXMAS
# 7       46947               003
# 8      191783          STAR_ROA
# 9      203097          T1241913
#
#                                                 Name                 Brand  \
# 0                   Best Friends Long Sleeve T-Shirt       Simply Southern
# 1       What Makes You Different Long Sleeve T-Shirt       Simply Southern
# 2             Appalachian Trail Short Sleeve T-Shirt  The Landmark Project
# 3  Mast General Store Double Exposure Black Bear ...               NO SHOW
# 4      Knoxville Rainbow Sphere Short Sleeve T-Shirt     Bacon And Company
# 5                       Tri Star Long Sleeve T-Shirt                Threds
# 6          Merry Christmas Truck Long Sleeve T-Shirt       Simply Southern
# 7                World Traveler Short Sleeve T-Shirt              Rocket 9
# 8  Mast General Store Roanoke Star Short Sleeve T...    Mast General Store
# 9          Women's Re Form Long Sleeve Flannel Shirt           Toad And Co
#
#                                          Lookup_List  \
# 0       11056396|11056397|11056398|11056399|11056400
# 1       11056386|11056387|11056388|11056389|11056390
# 2  10892557|10892558|10892559|10892560|10892561|1...
# 3  10932264|10932265|10932266|10932267|10932268|1...
# 4  10972273|10972274|10972275|10972276|10972277|1...
# 5  10700299|10700300|10700301|10700302|10700303|1...
# 6       11056416|11056417|11056418|11056419|11056420
# 7  10272994|10272995|10272996|10272997|10272998|1...
# 8  10905683|10905684|10905685|10905686|10905687|1...
# 9  10954772|10954773|10954774|10954775|10954776|1...
#
#                                        Taxonomy_List  \
# 0  T-SHIRTS & SWEATSHIRTS|WOMEN|T-SHIRTS & SWEATS...
# 1  T-SHIRTS & SWEATSHIRTS|WOMEN|T-SHIRTS & SWEATS...
# 2  MEN|T-SHIRTS & SWEATSHIRTS|MEN>T-SHIRTS & SWEA...
# 3  MAST COLLECTION|MEN|T-SHIRTS & SWEATSHIRTS|WOM...
# 4  T-SHIRTS & SWEATSHIRTS|T-SHIRTS & SWEATSHIRTS>...
# 5  MEN|T-SHIRTS & SWEATSHIRTS|WOMEN|MEN>T-SHIRTS ...
# 6  T-SHIRTS & SWEATSHIRTS|WOMEN|T-SHIRTS & SWEATS...
# 7  T-SHIRTS & SWEATSHIRTS|WOMEN|MEN>T-SHIRTS & SW...
# 8  MEN|T-SHIRTS & SWEATSHIRTS|WOMEN|MEN>T-SHIRTS ...
# 9                          WOMEN|WOMEN>SHIRTS & TOPS
#
#                                          Product_URL  Price  Retail_Price  \
# 0  /simply-southern/best-friends-long-sleeve-t-sh...  24.00         24.00
# 1  /simply-southern/what-makes-you-different-long...  24.00         24.00
# 2  /the-landmark-project/appalachian-trail-short-...  34.95         34.95
# 3  /no-show/mast-general-store-double-exposure-bl...  32.99         32.99
# 4  /bacon-and-company/knoxville-rainbow-sphere-sh...  24.99         24.99
# 5        /threds/tri-star-long-sleeve-t-shirt-141645  36.99         36.99
# 6  /simply-southern/merry-christmas-truck-long-sl...  24.00         24.00
# 7  /rocket-9/world-traveler-short-sleeve-t-shirt-...  19.99         19.99
# 8  /mast-general-store/mast-general-store-roanoke...  23.99         23.99
# 9  /toad-and-co/women-s-re-form-long-sleeve-flann...  80.00         80.00
#
#                      Thumbnail_URL                        Image_URL  \
# 0  /prodimages/71885-DEFAULT-s.jpg  /prodimages/71885-DEFAULT-l.jpg
# 1  /prodimages/71883-DEFAULT-s.jpg  /prodimages/71883-DEFAULT-l.jpg
# 2  /prodimages/62119-DEFAULT-s.jpg  /prodimages/62119-DEFAULT-l.jpg
# 3  /prodimages/57784-DEFAULT-s.jpg  /prodimages/57784-DEFAULT-l.jpg
# 4  /prodimages/71225-DEFAULT-s.jpg  /prodimages/71225-DEFAULT-l.jpg
# 5  /prodimages/71548-DEFAULT-s.jpg  /prodimages/71548-DEFAULT-l.jpg
# 6  /prodimages/71889-DEFAULT-s.jpg  /prodimages/71889-DEFAULT-l.jpg
# 7  /prodimages/20489-DEFAULT-s.jpg  /prodimages/20489-DEFAULT-l.jpg
# 8  /prodimages/58873-DEFAULT-s.jpg  /prodimages/58873-DEFAULT-l.jpg
# 9  /prodimages/66925-DEFAULT-s.jpg  /prodimages/66925-DEFAULT-l.jpg
#
#                                             Keywords  \
# 0  SIMPLY SOUTHERN, LS_BESTIE, 226574, Best Frien...
# 1  SIMPLY SOUTHERN, LS_DIFFERENT, 226572, What Ma...
# 2  THE LANDMARK PROJECT, APPALACHIAN TRAIL SS 36,...
# 3  HIGH RANGE, DBL EXP BLK BR MGS MTNS CALLING 60...
# 4  BACON AND COMPANY, KNOXVILLE RAINBOW SPHERE TO...
# 5  Threds, TRI_STAR_LS, 141645, Tri Star Long Sle...
# 6  SIMPLY SOUTHERN, MERRY CHRISTMAS TRUCK LS, 226...
# 7  World Traveler on Ice Grey SS, Rocket 9 Tee, M...
# 8  MAST GENERAL STORE, MGS STAR ROANOKE VA NL3604...
# 9  TOAD AND CO, RE FORM FLANNEL SHIRT, 203097, T1...
#
#                         Romantic_Copy_Short  \
# 0                                       NaN
# 1                                       NaN
# 2                                 YF - Copy
# 3                                Edit by YF
# 4                                        LS
# 5                                       NaN
# 6                                       NaN
# 7  <p>World Traveler on Ice Grey SS- LM</p>
# 8                                        YF
# 9                                 YF - Copy
#
#                                   Romantic_Copy_Long                 Color  \
# 0  <p>A shirt for making memories with your best ...                 LILAC
# 1  <p>Everyone is different! It&#39;s the qualiti...                 CREME
# 2  <p>From Springer Mountain to Katahdin, the App...                  DUNE
# 3  <p>A wearable memento from the Appalachian Mou...    SEAFOAM,WATERMELON
# 4  <p>Righteously retro, this short-sleeve t-shir...             HTR_ROYAL
# 5  <p>Fall is here, so the&nbsp;Tri Star Long Sle...       RED,ORANGE,GREY
# 6  <p>Don&#39;t let the chill hold you back from ...                 BLACK
# 7  <p>Rooted in the past and reissued for today, ...              ICE_GREY
# 8  <p>Let your star shine brightly in our&nbsp;Ma...        NATURAL_MAROON
# 9  <p>A true aficionado and devotee of the great ...  942_CANOE,257_BARLEY
#
#                Size  Inventory_Count
# 0      L,M,S,2XL,XL               38
# 1      M,L,S,XL,2XL               77
# 2        S,XL,2XL,M               52
# 3  XL,L,M,S,2XL,3XL              323
# 4                 M                2
# 5      L,XL,M,2XL,S              162
# 6      L,S,M,XL,2XL               40
# 7      M,S,2XL,L,XL               77
# 8                 L                1
# 9       L,S,M,XL,XS               22

# %%
df.Taxonomy_List.head()
# Out:
# 0    staff picks  toys  kids  toys  staff picks  to...
# 1    toys  kids  toys  toys  pretend play & dress-u...
# 2    outdoor gear  health & safety  outdoor gear  h...
# 3    outdoor gear  outdoor gear  health & safety  o...
# 4    outdoor gear  furniture & sleep systems  outdo...
# Name: Taxonomy_List, dtype: object
